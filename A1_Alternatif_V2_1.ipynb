# %% [markdown]
# <a href="https://colab.research.google.com/github/itzraf-lab/BetterChatGPT/blob/main/A1_Alternatif_V2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center>
#
# `Terakhir diperbarui : 22 JULI 2023 | 18:21 PM WIB INDONESIA`
#
# <img src="https://camo.githubusercontent.com/82291b0fe831bfc6781e07fc5090cbd0a8b912bb8b8d4fec0696c881834f81ac/68747470733a2f2f70726f626f742e6d656469612f394575424971676170492e676966" width="800" height="3">
#
#
# <font color="#CC3E3E"><font size="6"><u><b>PERHATIAN</b></u>
#
# Dikarenakan peraturan google collab yang terbaru <b><a href="https://research.google.com/colaboratory/faq.html#limitations-and-restrictions"> Google Colab ToS</a></b> dan <b><a href="https://twitter.com/thechrisperry/status/1649189902079381505"> Official Statement</a></b>, diharapkan jangan menjalankan script jika terdapat warning sebagai berikut
#
# ![image.png](data:image/png;base64,...)
#
# saya tidak bertanggung jawab apabila anda tetap menjalankan dan akun anda ditangguhkan sehingga tidak bisa menggunakan google colab dalam jangka waktu yang ditentukan google.
#
#
# <img src="https://camo.githubusercontent.com/82291b0fe831bfc6781e07fc5090cbd0a8b912bb8b8d4fec0696c881834f81ac/68747470733a2f2f70726f626f742e6d656469612f394575424971676170492e676966" width="800" height="3">

# %% [markdown]
# # **Jangan lupa dibaca sampai bawah**
# untuk menjalankan script ini tidak diperlukan spek tinggi karena menggunakan layanan berbasis cloud milik google. untuk kecepatan download file tergantung koneksi internet google dan juga banyaknya file yang didownload
#
# ---

# %% [markdown]
# > <font color="#00CED1">**INFORMASI**:</font>
#
# 1. Karena adanya [Kebijakan] dan [Pernyataan Resmi][pernyataanresmi] Google Colab yang baru, sebagai pengguna google colab gratis akan dibatasi untuk penggunaan GPU dan CUDA***(komputasinya dibatasi)***
# 2. Jika akun sudah limit pemakaian google colab akun tersebut akan bisa dipakai lagi dalam waktu 24 jam kedepan.
# (1 akun google memiliki batas 12 jam pemakiaan)
# 3. Dengan mengganti akun google yang dipakai akan mereset limit pemakaian, tetapi ada batasan jumlah pergantian penggunaan secara wajar (maksimal 3 akun, usahakan jangan lebih)
# 4. Google Colab Alternatife V2.1 mengambil Referensi Google Colab milik [Adiim EF] dan Milik [NoCrypt]
# 5. Google Colab Alternatife V2.2 mengambil Referensi Google Colab milik [Linaqruf][Linaqruf]
#
#
#
# [kebijakan]: https://research.google.com/colaboratory/faq.html#limitations-and-restrictions
# [adiim ef]: https://www.facebook.com/Adiim.EF
# [NoCrypt]:https://github.com/NoCrypt
# [pernyataanresmi]: https://twitter.com/thechrisperry/status/1649189902079381505
# [Linaqruf]:https://github.com/Linaqruf
# ---
#
# > <font color="#CC3E3E">**PERINGATAN**:</font>
#
# Jangan pernah sering mengganti akun untuk mengatasi limit pengguaan google colab, karena itu sudah termasuk dalam pelanggaran dalam [kebijakan baru][baru] (usahakan tidak menggunakan lebih dari 3 akun)
#
# [baru]:https://research.google.com/colaboratory/intl/id/faq.html
# ---
#
#
#
# > <font color="#00CER1">**NOTEBOOK COLLECTION**:</font>
#
# | Koleksi Catatan | Deskripsi | Link |
# | --- | --- | --- |
# | [Fast_stable_diffusion_AUTOMATIC1111](https://colab.research.google.com/drive/1B7gKPP1eHTPl62oGxptXm_gLSIfvR2ha?usp=sharing)  <font color="#FFD700">*Belum Stabil*</font>| Stable Diffuson V1.5 (TheLastBen) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1B7gKPP1eHTPl62oGxptXm_gLSIfvR2ha?usp=sharing) |  [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb) |
# | [Satu Klik Stable Diffusion](https://colab.research.google.com/drive/1LFohDgoe1U3rYwbAUFSLp1K6yM1QNG6i?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V1.5 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1LFohDgoe1U3rYwbAUFSLp1K6yM1QNG6i?usp=sharing) |
# | [Membuat LoRA](https://colab.research.google.com/drive/1wo3hz402iQTb1ilz6zv6g1sotMlM-qoS?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Google Colab Membuat LoRA  | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1wo3hz402iQTb1ilz6zv6g1sotMlM-qoS?usp=sharing) |
# | [Kohya LoRA Dreambooth](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb)  <font color="#7FFF00">*Normal*</font> | Membuat LoRA (Linaqruf) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb) |
# | [Kohya LoRA Finetuner](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-finetuner.ipynb)  <font color="#7FFF00">*Normal*</font> | Membuat LoRA 2 (Linaqruf) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-finetuner.ipynb) |
# | [Fast SD Chilloutmix](https://colab.research.google.com/drive/1Ty7uB6kZa_cfraZG-G6Rzu3B_spunJFy?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V1 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1Ty7uB6kZa_cfraZG-G6Rzu3B_spunJFy?usp=sharing) |
# | [Fast SD Shadow Garden](https://colab.research.google.com/drive/1zfLPHL7MKvFtIBxUezF0O_SVb6yS6W6I?usp=sharing)  <font color="#7FFF00">*Normal*</font> |Stable Diffusion V1|[![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1zfLPHL7MKvFtIBxUezF0O_SVb6yS6W6I?usp=sharing)|
# | [Alternatif Normal SD V2.1](https://colab.research.google.com/drive/1zxSTb-olxIfJeBslZL6H967_vEnzlGZi?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V2.1 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1zxSTb-olxIfJeBslZL6H967_vEnzlGZi?usp=sharing) |
# | [Alternatif Spesial SD V2.2](https://colab.research.google.com/drive/1pTC4P17ZkFKAxNX2UVnwU0c6bn8DRWwv?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1pTC4P17ZkFKAxNX2UVnwU0c6bn8DRWwv?usp=sharing)|
# | [Alternatif Spesial `KHUSUS SAWERIA`](https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing) |
# | [Alternatif Spesial Satu klik](https://colab.research.google.com/drive/1LjOYLyFgaeB2CAXVgmfkuK5mQ3XoAIRI#scrollTo=VNi70r9E4nPM)   <font color="#7FFF00">*Normal*</font> | Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1LjOYLyFgaeB2CAXVgmfkuK5mQ3XoAIRI#scrollTo=VNi70r9E4nPM) |
# |[Cagliostro-Colab-UI](https://colab.research.google.com/github/Linaqruf/sd-notebook-collection/blob/main/cagliostro-colab-ui.ipynb#scrollTo=SaAJk33ppFw1) <font color="#FFD700">**Main Source SD V2.2**</font>|Linaqruf Stable Diffusion|[![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/sd-notebook-collection/blob/main/cagliostro-colab-ui.ipynb#scrollTo=SaAJk33ppFw1)|
# | [Huggingface Collection Galery](https://huggingface.co/spaces/huggingface-projects/diffusers-gallery) | Koleksi Galeri Huggingface | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/huggingface-projects/diffusers-gallery)|
# | [VAE Collection](https://huggingface.co/vorstcavry/vaecollection/tree/main)| Koleksi VAE | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/vorstcavry/vaecollection/tree/main)|
# | [AI Voice Changer](https://huggingface.co/spaces/vorstcavry/vits-models) | AI Pengubah Suara | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/vorstcavry/vits-models)|
# | [AI Remove Background](https://huggingface.co/spaces/vorstcavry/anime-remove-background) | AI Penghapus Background | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/vorstcavry/anime-remove-background)|
# | [Stable Diffusion Extension](https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/Extensions) | Extension Stable Diffusion |[![Extension](https://badgen.net/badge/icon/GitHub?icon=github&label=Stable%20Diffusion)](https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/Extensions)|
#
# ---

# %% [markdown]
# ##Instalasi sekitar 7-10 menit
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# <CENTER>
#
# #<font color="#FFD700">***ALTERNATIF OLD VERSION V2.1***</font>
#
# <img src="https://user-images.githubusercontent.com/73097560/115834477-dbab4500-a447-11eb-908a-139a6edaec5c.gif" width="800" height="18">
#
#
#
# *Bagi yang mau support saya bisa menuju Saweria dan Trakteer dibawah ini*
#
#
#  <a href="https://saweria.co/VorstCavry"><img alt="Saweria" src="https://img.shields.io/badge/Saweria-7B3F00?style=for-the-badge&logo=ko-fi&logoColor=white"/></a> <a href="https://www.youtube.com/@remajapekalongan"><img alt="YOUTUBE" src="https://img.shields.io/badge/trakteer-F16061?style=for-the-badge&logo=buy-me-a-coffee&logoColor=white"/></a><a href="https://wa.me/6285726996330"><img alt="Whatsapp" src="https://img.shields.io/badge/WhatsApp-25D366?style=for-the-badge&logo=whatsapp&logoColor=white"/></a> <a href="https://www.youtube.com/@remajapekalongan"><img alt="YOUTUBE" src="https://img.shields.io/badge/YouTube-%23FF0000?style=for-the-badge&logo=YouTube&logoColor=white"/></a>
# <a href="https://www.paypal.com/paypalme/vorstcavry?country.x=ID&locale.x=id_ID"><img alt="PAYPAL" src="https://img.shields.io/badge/PayPal-00457C?style=for-the-badge&logo=paypal&logoColor=white"/></a>
# <a href="https://www.instagram.com/vorst_cavry/"><img alt="INSTAGRAM" src="https://img.shields.io/badge/Instagram-E4405F?style=for-the-badge&logo=instagram&logoColor=white"/></a> <a href="https://visitorbadge.io/status?path=https%3A%2F%2Fgithub.com%2Fvorstcavry"><img src="https://api.visitorbadge.io/api/visitors?path=https%3A%2F%2Fgithub.com%2Fvorstcavry&label=VISITORS&countColor=%23263759&labelStyle=none" /></a> <center/>

# %% [markdown]
# # **Jangan lupa dibaca sampai bawah**
# untuk menjalankan script ini tidak diperlukan spek tinggi karena menggunakan layanan berbasis cloud milik google. untuk kecepatan download file tergantung koneksi internet google dan juga banyaknya file yang didownload
#
# ---

# %% [markdown]
# > <font color="#00CED1">**INFORMASI**:</font>
#
# 1. Karena adanya [Kebijakan] dan [Pernyataan Resmi][pernyataanresmi] Google Colab yang baru, sebagai pengguna google colab gratis akan dibatasi untuk penggunaan GPU dan CUDA***(komputasinya dibatasi)***
# 2. Jika akun sudah limit pemakaian google colab akun tersebut akan bisa dipakai lagi dalam waktu 24 jam kedepan.
# (1 akun google memiliki batas 12 jam pemakiaan)
# 3. Dengan mengganti akun google yang dipakai akan mereset limit pemakaian, tetapi ada batasan jumlah pergantian penggunaan secara wajar (maksimal 3 akun, usahakan jangan lebih)
# 4. Google Colab Alternatife V2.1 mengambil Referensi Google Colab milik [Adiim EF] dan Milik [NoCrypt]
# 5. Google Colab Alternatife V2.2 mengambil Referensi Google Colab milik [Linaqruf][Linaqruf]
#
#
#
# [kebijakan]: https://research.google.com/colaboratory/faq.html#limitations-and-restrictions
# [adiim ef]: https://www.facebook.com/Adiim.EF
# [NoCrypt]:https://github.com/NoCrypt
# [pernyataanresmi]: https://twitter.com/thechrisperry/status/1649189902079381505
# [Linaqruf]:https://github.com/Linaqruf
# ---
#
# > <font color="#CC3E3E">**PERINGATAN**:</font>
#
# Jangan pernah sering mengganti akun untuk mengatasi limit pengguaan google colab, karena itu sudah termasuk dalam pelanggaran dalam [kebijakan baru][baru] (usahakan tidak menggunakan lebih dari 3 akun)
#
# [baru]:https://research.google.com/colaboratory/intl/id/faq.html
# ---
#
#
#
# > <font color="#00CER1">**NOTEBOOK COLLECTION**:</font>
#
# | Koleksi Catatan | Deskripsi | Link |
# | --- | --- | --- |
# | [Fast_stable_diffusion_AUTOMATIC1111](https://colab.research.google.com/drive/1B7gKPP1eHTPl62oGxptXm_gLSIfvR2ha?usp=sharing)  <font color="#FFD700">*Belum Stabil*</font>| Stable Diffuson V1.5 (TheLastBen) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1B7gKPP1eHTPl62oGxptXm_gLSIfvR2ha?usp=sharing) |  [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb) |
# | [Satu Klik Stable Diffusion](https://colab.research.google.com/drive/1LFohDgoe1U3rYwbAUFSLp1K6yM1QNG6i?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V1.5 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1LFohDgoe1U3rYwbAUFSLp1K6yM1QNG6i?usp=sharing) |
# | [Membuat LoRA](https://colab.research.google.com/drive/1wo3hz402iQTb1ilz6zv6g1sotMlM-qoS?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Google Colab Membuat LoRA  | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1wo3hz402iQTb1ilz6zv6g1sotMlM-qoS?usp=sharing) |
# | [Kohya LoRA Dreambooth](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb)  <font color="#7FFF00">*Normal*</font> | Membuat LoRA (Linaqruf) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-dreambooth.ipynb) |
# | [Kohya LoRA Finetuner](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-finetuner.ipynb)  <font color="#7FFF00">*Normal*</font> | Membuat LoRA 2 (Linaqruf) | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/kohya-trainer/blob/main/kohya-LoRA-finetuner.ipynb) |
# | [Fast SD Chilloutmix](https://colab.research.google.com/drive/1Ty7uB6kZa_cfraZG-G6Rzu3B_spunJFy?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V1 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1Ty7uB6kZa_cfraZG-G6Rzu3B_spunJFy?usp=sharing) |
# | [Fast SD Shadow Garden](https://colab.research.google.com/drive/1zfLPHL7MKvFtIBxUezF0O_SVb6yS6W6I?usp=sharing)  <font color="#7FFF00">*Normal*</font> |Stable Diffusion V1|[![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1zfLPHL7MKvFtIBxUezF0O_SVb6yS6W6I?usp=sharing)|
# | [Alternatif Normal SD V2.1](https://colab.research.google.com/drive/1zxSTb-olxIfJeBslZL6H967_vEnzlGZi?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V2.1 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1zxSTb-olxIfJeBslZL6H967_vEnzlGZi?usp=sharing) |
# | [Alternatif Spesial SD V2.2](https://colab.research.google.com/drive/1pTC4P17ZkFKAxNX2UVnwU0c6bn8DRWwv?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1pTC4P17ZkFKAxNX2UVnwU0c6bn8DRWwv?usp=sharing)|
# | [Alternatif Spesial Lite `KHUSUS SAWERIA`](https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing)  <font color="#7FFF00">*Normal*</font> | Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing) |
# | [Alternatif Spesial Satu klik](https://colab.research.google.com/drive/1LjOYLyFgaeB2CAXVgmfkuK5mQ3XoAIRI#scrollTo=VNi70r9E4nPM)   <font color="#7FFF00">*Normal*</font> | Stable Diffuson V2.2 | [![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/drive/1LjOYLyFgaeB2CAXVgmfkuK5mQ3XoAIRI#scrollTo=VNi70r9E4nPM) |
# |[Cagliostro-Colab-UI](https://colab.research.google.com/github/Linaqruf/sd-notebook-collection/blob/main/cagliostro-colab-ui.ipynb#scrollTo=SaAJk33ppFw1) <font color="#FFD700">**Main Source SD V2.2**</font>|Linaqruf Stable Diffusion|[![](https://img.shields.io/static/v1?message=Open%20in%20Colab&logo=googlecolab&labelColor=5c5c5c&color=0f80c1&label=%20&style=flat)](https://colab.research.google.com/github/Linaqruf/sd-notebook-collection/blob/main/cagliostro-colab-ui.ipynb#scrollTo=SaAJk33ppFw1)|
# | [Huggingface Collection Galery](https://huggingface.co/spaces/huggingface-projects/diffusers-gallery) | Koleksi Galeri Huggingface | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/huggingface-projects/diffusers-gallery)|
# | [VAE Collection](https://huggingface.co/vorstcavry/vaecollection/tree/main)| Koleksi VAE | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/vorstcavry/vaecollection/tree/main)|
# | [AI Voice Changer](https://huggingface.co/spaces/vorstcavry/vits-models) | AI Pengubah Suara | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/vorstcavry/vits-models)|
# | [AI Remove Background](https://huggingface.co/spaces/vorstcavry/anime-remove-background) | AI Penghapus Background | [![Hugging Face Spaces](https://img.shields.io/badge/%F0%9F%A4%97%20Hugging%20Face-Spaces-blue)](https://huggingface.co/spaces/vorstcavry/anime-remove-background)|
# | [Stable Diffusion Extension](https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/Extensions) | Extension Stable Diffusion |[![Extension](https://badgen.net/badge/icon/GitHub?icon=github&label=Stable%20Diffusion)](https://github.com/AUTOMATIC1111/stable-diffusion-webui/wiki/Extensions)|
#
# ---

# %% [markdown]
# ##Instalasi sekitar 7-10 menit
#
# ![image.png](data:image/png;base64,...)
#
# ---

# %% [markdown]
# ## <font color="#FFD700">***ALTERNATIF V2.1***</font>

# %%
#@markdown #<font color="#7FFF00">***JALANKAN STABLE DIFFUSION***</font>
#Deklarasi variabel. modul, dan fungsi

#Variabel
pt      = ".pt"
st      = ".safetensors"
civitai = "https://civitai.com/api/download/models/"
masbro  = {

      0  : ( "stable"    )
    , 1  : ( "diffusion" )
    , 2  : ( "webui"     )
    , 3  : ( "sd"        )
    , 4  : ( "Stable"    )
    , 5  : ( "Diffusion" )
    , 6  : ( "WebUI"     )
    , 7  : ( "SD"        )

}
#Import modul
from   datetime        import datetime
from   IPython.display import clear_output

#Lokasi folder
sd                = f"{masbro[0]}-{masbro[1]}"
wui               = f"{masbro[2]}"
sdwui             = f"{sd}-{wui}"
basemodelpath     = f"/content/vorst-cavry/models/Stable-diffusion"
vaepath           = f"/content/vorst-cavry/models/VAE"
embeddingpath     = f"/content/vorst-cavry/embeddings"
loramodelpath     = f"/content/vorst-cavry/models/Lora"
rooppath          = f"/content/vorst-cavry/models/roop"
contrlnetpath     = f"/content/vorst-cavry/extensions/sd-{wui}-controlnet/models"
addnetworkpath    = f"/content/vorst-cavry/extensions/sd-{wui}-additional-networks/models/lora"
esrganpath        = f"/content/vorst-cavry/models/ESRGAN"

def isnumber(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

# %cd /content


# !apt-get -y install -qq aria2
# !pip install --upgrade fastapi==0.90.1
# !pip install triton
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 torchmetrics==0.11.4 --extra-index-url https://download.pytorch.org/whl/cu116 -U

#!apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev
#!pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 torchmetrics==0.11.4 --extra-index-url https://download.pytorch.org/whl/cu116 -U

# %cd /content
#install-stablediffusion
# !git clone -b v2.1 https://github.com/camenduru/$sdwui /content/vorst-cavry
# !git clone https://github.com/vorstcavry/tunnels /content/vorst-cavry/extensions/$sdwui-tunnels
# !wget https://raw.githubusercontent.com/camenduru/$sdwui-scripts/main/run_n_times.py -O /content/vorst-cavry/scripts/run_n_times.py
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-$wui-locon /content/vorst-cavry/extensions/a1111-sd-$wui-locon
# !git -C /content/vorst-cavry/extensions/a1111-sd-$wui-locon reset --hard 04b768b
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-$wui-lycoris /content/vorst-cavry/extensions/a1111-sd-$wui-lycoris
#install-bahan-dasar
# !git clone https://github.com/vorstcavry/lora /content/vorst-cavry/models/Lora/Lora-set
# !git clone https://github.com/vorstcavry/embeddings /content/vorst-cavry/embeddings/negative
#install-deforum
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-$wui /content/vorst-cavry/extensions/deforum-for-automatic1111-$wui
# !git -C /content/vorst-cavry/extensions/deforum-for-automatic1111-$wui fetch
# !git -C /content/vorst-cavry/extensions/deforum-for-automatic1111-$wui checkout 0056c493e0dd44d2524175564f8fb91e40c94c59
#instal-Preview
# !git clone https://github.com/vorstcavry/Checkpoint-Model /content/vorst-cavry/models/Stable-diffusion/Checkpoint-Model
#install-upscale
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d /content/vorst-cavry/models/ESRGAN -o 4x-UltraSharp.pth
#install-ekstension
# %cd /content/vorst-cavry/extensions
# !git clone https://github.com/Klace/$sdwui-images-browser
# !git clone https://github.com/Iyashinouta/sd-model-downloader
# !git clone https://github.com/camenduru/sd-civitai-browser
# !git clone https://github.com/camenduru/sd-$wui-additional-networks
# !git clone https://github.com/Mikubill/sd-$wui-controlnet
# !git clone https://github.com/fkunn1326/openpose-editor
# !git clone https://github.com/jexom/sd-$wui-depth-lib
# !git clone https://github.com/hnmr293/posex
# !git clone https://github.com/vorstcavry/roop
# !git clone https://github.com/DominikDoom/a1111-sd-$wui-tagcomplete
# !git clone https://github.com/etherealxx/batchlinks-$wui
# !git clone https://github.com/camenduru/$sdwui-catppuccin
# !git clone https://github.com/AUTOMATIC1111/$sdwui-rembg
# !git clone https://github.com/thomasasfk/sd-$wui-aspect-ratio-helper
# !git clone https://github.com/tjm35/asymmetric-tiling-sd-$wui
# %cd /content/vorst-cavry
# !git reset --hard
# !git -C /content/vorst-cavry/repositories/$sd-stability-ai reset --hard
# %cd /content/vorst-cavry


#install-controlnet
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_canny-fp16.safetensors -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o control_canny-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_depth-fp16.safetensors -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o control_depth-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_hed-fp16.safetensors -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o control_hed-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_mlsd-fp16.safetensors -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o control_mlsd-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_normal-fp16.safetensors -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o control_normal-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_openpose-fp16.safetensors -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o control_openpose-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_scribble-fp16.safetensors -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o control_scribble-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_seg-fp16.safetensors -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o control_seg-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/hand_pose_model.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o hand_pose_model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/body_pose_model.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o body_pose_model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/dpt_hybrid-midas-501f0c75.pt -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o dpt_hybrid-midas-501f0c75.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_large_512_fp32.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o mlsd_large_512_fp32.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_tiny_512_fp32.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o mlsd_tiny_512_fp32.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/network-bsds500.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o network-bsds500.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/upernet_global_small.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o upernet_global_small.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_style_sd14v1.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o t2iadapter_style_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_sketch_sd14v1.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o t2iadapter_sketch_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_seg_sd14v1.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o t2iadapter_seg_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_openpose_sd14v1.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o t2iadapter_openpose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_keypose_sd14v1.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o t2iadapter_keypose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_depth_sd14v1.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o t2iadapter_depth_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_color_sd14v1.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o t2iadapter_color_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_canny_sd14v1.pth -d /content/vorst-cavry/extensions/sd-$wui-controlnet/models -o t2iadapter_canny_sd14v1.pth

#install-vae-untuk-model-checkpoint-yang-akan-dipakai
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/stabilityai/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d $vaepath -o vae-ft-mse-840000-ema-pruned.ckpt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/vaecollection/resolve/main/clearvae_main.safetensors -d $vaepath -o clearvae_main.safetensors

#install-lora
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia/resolve/main/japaneseDollLikeness_v15.safetensors -d /content/vorst-cavry/models/Lora/Lora-set -o japaneseDollLikeness_v15.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia/resolve/main/koreanDollLikeness_v20.safetensors -d /content/vorst-cavry/models/Lora/Lora-set -o koreanDollLikeness_v20.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia/resolve/main/taiwanDollLikeness_v15.safetensors -d /content/vorst-cavry/models/Lora/Lora-set -o taiwanDollLikeness_v15.safetensors

#intsall-lora-di-additional-networks
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia/resolve/main/japaneseDollLikeness_v15.safetensors -d $addnetworkpath -o japaneseDollLikeness_v15.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia/resolve/main/koreanDollLikeness_v20.safetensors -d $addnetworkpath -o koreanDollLikeness_v20.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/loraasia/resolve/main/taiwanDollLikeness_v15.safetensors -d $addnetworkpath -o taiwanDollLikeness_v15.safetensors

#Install-roop
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/henryruhs/roop/resolve/main/inswapper_128.onnx -d  /content/vorst-cavry/models/roop -o inswapper_128.onnx

#@markdown ### <font color="#00CED1">**PILIH MODEL**</font>

#@markdown <font color="#CC3E3E">**JANGAN CENTANG SEMUA!!!**</font>
ChillOutMix = True #@param {type:"boolean"}
#@markdown &nbsp; &nbsp;<img src="https://i.postimg.cc/JzRNw2CG/00014-3953222432-11zon.jpg?size=50" width="170"/>
MeinaPastel = False #@param {type:"boolean"}
#@markdown &nbsp; &nbsp;<img src="https://i.postimg.cc/9FPw3Yyv/00137-2497764668-11zon.jpg?size=50" width="170"/>
PerfectWorld = False #@param {type:"boolean"}
#@markdown &nbsp; &nbsp;<img src="https://i.postimg.cc/RF9KJp1Q/291612-11zon.jpg?size=50" width="164"/>
Figure = False #@param {type:"boolean"}
#@markdown &nbsp; &nbsp;<img src="https://i.postimg.cc/zv7sYQ7d/326039-11zon.jpg?size=50" width="158"/>
DosMix = False #@param {type:"boolean"}
#@markdown &nbsp; &nbsp;<img src="https://i.postimg.cc/HWFZVdcQ/00008-1109568103-11zon.jpg?size=50" width="160"/>
RevAnimated = False #@param {type:"boolean"}
#@markdown &nbsp; &nbsp;<img src="https://i.postimg.cc/YCDmCqj7/368736.png?size=50" width="160"/>
MeinaMix = False #@param {type:"boolean"}
#@markdown &nbsp; &nbsp;<img src="https://i.postimg.cc/W4Vxtjy9/341494-11zon.jpg?size=50" width="160"/>
CyberReal  = False #@param {type:"boolean"}
#@markdown &nbsp; &nbsp;<img src="https://i.postimg.cc/XXSXCpdG/00003-771431371.jpg?size=50" width="160"/>


with open("models.txt", "w") as f:
     if ChillOutMix:
        f.write("https://huggingface.co/AnonPerson/ChilloutMix/resolve/main/ChilloutMix-ni-fp16.safetensors\n"
                " out=ChilloutMix.safetensors\n")
     else:
          pass
     if MeinaPastel:
        f.write("https://huggingface.co/Meina/MeinaPastel/resolve/main/MeinaPastelV4%20-%20Without%20VAE.safetensors\n"
                " out=MeinaPastel.safetensors\n")
     else:
          pass
     if PerfectWorld:
        f.write("https://huggingface.co/ckpt/perfect_world/resolve/main/perfectWorld_v2Baked.safetensors\n"
                " out=Perfect_World.safetensors\n")
     else:
          pass
     if Figure :
        f.write("https://huggingface.co/vorstcavry/figurestyle/resolve/main/figure.safetensors\n"
                " out=Figure.safetensors\n")
     else:
          pass
     if DosMix :
       f.write("https://huggingface.co/vorstcavry/dosmix/resolve/main/ddosmix_V2.safetensors\n"
                " out=Dosmix.safetensors\n")
     else:
          pass
     if RevAnimated :
       f.write("https://huggingface.co/ckpt/rev-animated/resolve/main/revAnimated_v11.safetensors\n"
                " out=RevAnmated.safetensors\n")
     else:
          pass
     if MeinaMix :
       f.write("https://huggingface.co/ckpt/MeinaMix/resolve/main/Meina_V8_baked_VAE.safetensors\n"
                " out=Meina_V8_baked_VAE.safetensors\n")
     else:
          pass
     if CyberReal :
       f.write("https://huggingface.co/ckpt/CyberRealistic/resolve/main/cyberrealistic_v13.safetensors\n"
                " out=CyberRealistic.safetensors\n")
     else:
          pass
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M --input-file models.txt -d /content/vorst-cavry/models/Stable-diffusion/Checkpoint-Model
# !rm -rf /content/models.txt

#Tambahan-data
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/vorstcavry/mymodel/resolve/main/Cavry_V2.safetensors -d /content/vorst-cavry/models/Stable-diffusion/Checkpoint-Model -o Cavry_V2.safetensors


#Menjalankan web
# %cd /content/vorst-cavry

# !sed -i -e '''/    prepare_environment()/a\    os.system\(f\"""sed -i -e ''\"s/dict()))/dict())).cuda()/g\"'' /content/vorst-cavry/repositories/stable-diffusion-stability-ai/ldm/util.py""")''' /content/vorst-cavry/launch.py
# !sed -i -e 's/\"sd_model_checkpoint\"\,/\"sd_model_checkpoint\,sd_vae\,CLIP_stop_at_last_layers\"\,/g' /content/vorst-cavry/modules/shared.py

# !python launch.py --listen --xformers --enable-insecure-extension-access --theme dark --gradio-queue --multiple --reinstall-xformers --reinstall-torch

# %% [markdown]
# ## Tunggu sampai link  muncul 👆
#
# tunggu semua proses selesi agar link muncul, di sini tersedia 4 link (kadang ada 1-3 link karena menyesuaikan server yang bisa di pakai)
#
# **KLIK SALAH SATU, JIKA SALAH SATU LINK MENGALAMI ERROR BISA GANTI DENGAN LINK SATUNYA LAGI**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##<b><u>INDONESIA</u></b>
# #Untuk notebook Google Colab Alternative V2.2 telah dipindahkan ke Link Notebook Google Colab Baru
# ---
# ##INI LINK UNTUK ALTERNATIFE V2.2
# # <B>[TEKAN DISINI]<B/>
# [TEKAN DISINI]:https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing
# ---
# ##<b><u>ENGLISH</u></b>
# #For Google Colab Alternative V2.2 notebooks have been moved to the New Google Colab Notebook Link
# ---
#
# ##THIS LINK FOR ALTERNATIFE V2.2
# ## <B>[CLICK HERE]<B/>
# [CLICK HERE]:https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing

# %% [markdown]
# ## <center><font color="#CC3E3E"><font size="6"><u><b>TIDAK DI REKOMENDASIKAN UNTUK PENGGUNA YANG INGIN PROSESNYA CEPAT</b></u>
#
# ##<center><b>KARENA PROSESNYA LAMA, TETAPI EFEKTIF UNTUK PENGGUNAAN JANGKA PANJANG. [KLIK DISINI] UNTUK MENGGUNAKAN GOOGLE COLAB VERSI CEPAT
#
# [KLIK DISINI]:https://colab.research.google.com/drive/1cRZwgt0WvJCDML4OI860fYKF2HaDW6SY?usp=sharing
#
# HEHEHE :)</b>
